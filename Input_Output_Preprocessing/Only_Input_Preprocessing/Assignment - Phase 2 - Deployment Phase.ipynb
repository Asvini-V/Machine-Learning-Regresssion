# %%
import pandas as pd
import pickle

# %%
loaded_sc = pickle.load(open("scaler_SVMReg_Asgn.sav", 'rb'))
pre_input=loaded_sc.transform([[1300, 1200, 4000, 0, 1]])
pre_input
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([[-1.46755405, -4.75759929, -1.50744257, -0.5       ,  1.30088727]])

# %%
loaded_model=pickle.load(open("finalized_model_SVMReg.sav", 'rb')) 
result=loaded_model.predict(pre_input)
result
# Out:
# array([40378.1029])
