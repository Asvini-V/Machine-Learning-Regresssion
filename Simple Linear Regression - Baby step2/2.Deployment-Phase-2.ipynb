# %%
import pickle # Imports the pickle module, which is used to load saved machine learning models.

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav", 'rb')) # Loads the saved Linear Regression model from the file 
result=loaded_model.predict([[13]]) # Uses the loaded model to predict the output

# %%
result # Displays the predicted salary value
# Out:
# array([[148460.78806172]])
